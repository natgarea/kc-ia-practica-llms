# %% [markdown]
# # Dataset
#
# En este notebook examinamos brevemente el dataset de organizaciones benéficas que se utiliza como base de conocimiento para el sistema RAG y que se ha generado sintéticamente para la prueba de concepto.

# %%
import pandas as pd

df = pd.read_csv("../data/100_charities.csv")
df.shape
df.head()
# Out:
#    id                        name                      cause  \
# 0   1  Against Malaria Foundation         Malaria prevention
# 1   2          Malaria Consortium         Malaria prevention
# 2   3  Helen Keller International                  Nutrition
# 3   4              New Incentives  Maternal and child health
# 4   5                GiveDirectly             Cash transfers
#
#                                      regions         source_primary  \
# 0                         Sub-Saharan Africa               GiveWell
# 1          Sub-Saharan Africa (Sahel region)               GiveWell
# 2                Sub-Saharan Africa and Asia               GiveWell
# 3                                    Nigeria               GiveWell
# 4  Kenya Uganda Rwanda Malawi Mozambique DRC  The Life You Can Save
#
#                                           source_url  \
# 0  https://www.givewell.org/charities/against-mal...
# 1  https://www.givewell.org/charities/malaria-con...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  100 non-null    int64
#  1   name                100 non-null    object
#  2   cause               100 non-null    object
#  3   regions             100 non-null    object
#  4   source_primary      100 non-null    object
#  5   source_url          100 non-null    object
#  6   evidence_text       100 non-null    object
#  7   transparency_notes  100 non-null    object
#  8   transparency_url    100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
# Organizaciones por fuente
df["source_primary"].value_counts()
# Out:
# source_primary
# The Life You Can Save    56
# GiveWell                 24
# Founders Pledge          14
# Evidence Action           6
# Name: count, dtype: int64

# %%
# Organizaciones por causa
df["cause"].value_counts()
# Out:
# cause
# Malaria prevention              3
# Maternal and child health       3
# Health systems strengthening    3
# Nutrition                       3
# School-based deworming          3
#                                ..
# Water quality                   1
# Health technology               1
# Data and evaluation             1
# Social marketing for health     1
# Neonatal care                   1
# Name: count, Length: 85, dtype: int64

# %%
# 3 ejemplos
df.sample(3)
# Out:
#     id                                      name                      cause  \
# 96  97                     Agroforestry Programs     Tree-based agriculture
# 77  78  Smallholder Agriculture Support Programs  Agricultural productivity
# 23  24            Innovations for Poverty Action    Research and evaluation
#
#                regions         source_primary  \
# 96  Sub-Saharan Africa  The Life You Can Save
# 77  Sub-Saharan Africa  The Life You Can Save
# 23              Global        Founders Pledge
#
#                                            source_url  \
# 96  https://www.thelifeyoucansave.org/best-chariti...
# 77  https://www.thelifeyoucansave.org/best-chariti...
# 23  https://www.founderspledge.com/programs/global...
#
#                                         evidence_text  \
# 96  Tree planting initiatives integrated with farm...
# 77  Provision of quality seeds, fertilizer, traini...
# 23  Conducts rigorous randomized controlled trials...
#
# ...
